# %%
import pandas as pd
import numpy as np
import echopype as ep
import os

# %%
# Open echosounder raw file
print(os.getcwd())
os.chdir(r"C:\Users\kcn33\github\ON_long_term_acoustics")
print(os.getcwd())
#ed = ep.open_raw("FILENAME.raw", sonar_model="EK80")  # for EK80 file
# Out:
# C:\Users\kcn33\github\ON_long_term_acoustics
# C:\Users\kcn33\github\ON_long_term_acoustics

# %%
# Save as either netCDF or Zarr file format
ed.to_netcdf(save_path="./unpacked_files")  # save to FILENAME.nc in the folder unpacked_files
ed.to_zarr(save_path="./unpacked_files/NEW_FILENAME.zarr")  # fully specify filename also works
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Save as either netCDF or Zarr file format
# ----> 2 ed.to_netcdf(save_path="./unpacked_files")  # save to FILENAME.nc in the folder unpacked_files
#       3 ed.to_zarr(save_path="./unpacked_files/NEW_FILENAME.zarr")  # fully specify filename also works
#
# NameError: name 'ed' is not defined
