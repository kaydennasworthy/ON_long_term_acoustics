# %%
import matplotlib.pyplot as plt

import echopype as ep

# Grab one file from the OOI file server
raw_url ="https://rawdata.oceanobservatories.org/files/CE04OSPS/PC01B/ZPLSCB102_10.33.10.143/2017/08/21/OOI-D20170821-T163049.raw"

# Convert the raw file into an EchoDat object
echodata = ep.open_raw(raw_file=raw_url, sonar_model="EK60")

# Calibrate the raw data to volume backscattering volume (Sv)
ds_Sv = ep.calibrate.compute_Sv(echodata, waveform_mode="CW", encode_mode="power")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 9
#       6 raw_url ="https://rawdata.oceanobservatories.org/files/CE04OSPS/PC01B/ZPLSCB102_10.33.10.143/2017/08/21/OOI-D20170821-T163049.raw"
#       8 # Convert the raw file into an EchoDat object
# ----> 9 echodata = ep.open_raw(raw_file=raw_url, sonar_model="EK60")
#      11 # Calibrate the raw data to volume backscattering volume (Sv)
#      12 ds_Sv = ep.calibrate.compute_Sv(echodata, waveform_mode="CW", encode_mode="power")
#
# File ~\AppData\Local\miniforge3\Lib\site-packages\echopype\utils\prov.py:241, in add_processing_level.<locals>.wrapper.<locals>.inner(*args, **kwargs)
#     239 @functools.wraps(func)
#     240 def inner(*args, **kwargs):
# --> 241     dataobj = func(*args, **kwargs)
#     242     if is_echodata:
#     243         ed = dataobj
#
# File ~\AppData\Local\miniforge3\Lib\site-packages\echopype\convert\api.py:456, in open_raw(raw_file, sonar_model, xml_path, include_bot, include_idx, convert_params, storage_options, use_swap, max_chunk_size)
#     451     raise ValueError(
#     452         f"Unsupported echosounder model: {sonar_model}\nMust be one of: {list(SONAR_MODELS)}"  # noqa
#     453     )
#     455 # Check file extension and existence
# --> 456 file_chk, xml_chk, bot_chk, idx_chk = _check_file(
#     457     raw_file, sonar_model, xml_path, include_bot, include_idx, storage_options
#     458 )
#     460 # Parse raw file and organize data into groups
#     461 parser = SONAR_MODELS[sonar_model]["parser"](
#     462     file_chk,
#     463     # Currently used only for AZFP XML File
#    (...)    469     sonar_model=sonar_model,
#     470 )
#
# File ~\AppData\Local\miniforge3\Lib\site-packages\echopype\convert\api.py:340, in _check_file(raw_file, sonar_model, xml_path, include_bot, include_idx, storage_options)
#     338 validate_ext = SONAR_MODELS[sonar_model]["validate_ext"]
#     339 if not fsmap.fs.exists(fsmap.root):
# --> 340     raise FileNotFoundError(f"There is no file named {Path(raw_file).name}")
#     341 validate_ext(Path(raw_file).suffix.upper())
#     343 return str(raw_file), str(xml), bot_file, idx_file
#
# FileNotFoundError: There is no file named OOI-D20170821-T163049.raw

# %%
<xarray.plot.facetgrid.FacetGrid at 0x10411f910>
